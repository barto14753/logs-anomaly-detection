# %% [markdown]
# # Logs anomaly detection
# * Bartosz Włodarski
# * Maciej Zdański

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# ## Anomaly detection using `IsolationForest` model

# %% [markdown]
# The `Isolation Forest` model is an unsupervised machine learning algorithm used for anomaly detection. It is based on the principle that anomalies are data points that are few and different from the majority of the data points.
#
# Isolation Forest has several advantages for anomaly detection:
# * It can efficiently handle high-dimensional data.
# * It doesn't require a large amount of data for training.
# * It's robust to outliers and doesn't require tuning of hyperparameters.

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv("result_data.csv")

# Preprocessing: Convert Time column to datetime
df['Time'] = pd.to_datetime(df['Time'])
df.set_index('Time', inplace=True)

# Select features for anomaly detection
features = df[['Duration', 'SrcPackets', 'DstPackets', 'SrcBytes', 'DstBytes']]

# Train Isolation Forest model
model = IsolationForest(contamination=0.05)
model.fit(features)

# Predict outliers/anomalies
predictions = model.predict(features)
anomalies = df[predictions == -1]

# Print the anomalies
print("Anomalies:")
print(anomalies)
# Out:
# Anomalies:
#                                Duration   SrcDevice   DstDevice  Protocol  \
# Time
# 1970-01-01 00:00:00.003715200         0  Comp107130  Comp906925         6
# 1970-01-01 00:00:00.003715200         0  Comp107130  Comp995183         6
# 1970-01-01 00:00:00.003715200         0  Comp107130  Comp847595         6
# 1970-01-01 00:00:00.003715200         1  Comp700191  Comp639264         6
# 1970-01-01 00:00:00.003715200         1  Comp453311  Comp278079         6
# ...                                 ...         ...         ...       ...
# 1970-01-01 00:00:00.003715736         1  Comp024668  Comp604291         6
# 1970-01-01 00:00:00.003715736         1  Comp024668  Comp392461         6
# 1970-01-01 00:00:00.003715736         1  Comp415540  Comp576031        17
# 1970-01-01 00:00:00.003715736         1  Comp343095  Comp418766         6
# 1970-01-01 00:00:00.003715736         1  Comp697547  Comp239359        17
#
# ...

# %% [markdown]
# ## Timeseries plots

# %%
def show_column_with_anomalies(column):
    plt.figure(figsize=(12, 6))
    plt.plot(features.index, features[column], color='blue', label='Normal Data')
    plt.scatter(anomalies.index, anomalies[column], color='red', label='Outliers')
    plt.title(f'Time Series of {column} with Outliers')
    plt.xlabel('Time')
    plt.ylabel(column)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
show_column_with_anomalies("Duration")

# %%
show_column_with_anomalies("SrcPackets")

# %%
show_column_with_anomalies("DstPackets")

# %%
show_column_with_anomalies("SrcBytes")

# %%
show_column_with_anomalies("DstBytes")
