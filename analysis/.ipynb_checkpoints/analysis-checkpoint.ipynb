# %% [markdown]
# # Logs anomaly detection
# * Bartosz Włodarski
# * Maciej Zdański

# %%
# !pip3 install pandas --upgrade pip
# !pip3 install sckit-learn
# !pip3 install matplotlib
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement sckit-learn (from versions: none)
# ERROR: No matching distribution found for sckit-learn
# ...

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# ## Anomaly detection using `IsolationForest` model

# %% [markdown]
# The `Isolation Forest` model is an unsupervised machine learning algorithm used for anomaly detection. It is based on the principle that anomalies are data points that are few and different from the majority of the data points.
#
# Isolation Forest has several advantages for anomaly detection:
# * It can efficiently handle high-dimensional data.
# * It doesn't require a large amount of data for training.
# * It's robust to outliers and doesn't require tuning of hyperparameters.

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv("/Users/bartek/logs-anomaly-detection/analysis/result_data.csv")

# Preprocessing: Convert Time column to datetime
df['Time_formatted'] = pd.to_datetime(df['Time'])
df.set_index('Time_formatted', inplace=True)

# Select features for anomaly detection
features = df[['Duration', 'SrcPackets', 'DstPackets', 'SrcBytes', 'DstBytes']]

# Train Isolation Forest model
model = IsolationForest(contamination=0.01)
model.fit(features)

# Predict outliers/anomalies
predictions = model.predict(features)
anomalies = df[predictions == -1]
normal_logs = df[predictions != -1]

# Print number of anomalies
number_of_logs = df.size
number_of_anomalies = anomalies.size
print(f"Number of logs: {number_of_logs}") 
print(f"Number of anomalies: {number_of_anomalies}")
print(f"Percent of anomalies: {100 * number_of_anomalies / number_of_logs} %")

# Print the anomalies
print("Anomalies:")
print(anomalies)
# Out:
# Number of logs: 11534336
# Number of anomalies: 115346
# Percent of anomalies: 1.0000228881835938 %
# Anomalies:
#                                   Time  Duration   SrcDevice  \
# Time_formatted
# 1970-01-01 00:00:00.003715200  3715200         1  Comp005825
# 1970-01-01 00:00:00.003715200  3715200         1  Comp373286
# 1970-01-01 00:00:00.003715200  3715200         1  Comp216639
# 1970-01-01 00:00:00.003715200  3715200         2  Comp252302
# 1970-01-01 00:00:00.003715200  3715200         3  Comp955278
# ...                                ...       ...         ...
# 1970-01-01 00:00:00.003715735  3715735        94  Comp521099
# 1970-01-01 00:00:00.003715735  3715735     14118  Comp987487
# 1970-01-01 00:00:00.003715735  3715735     26263  Comp987487
# 1970-01-01 00:00:00.003715735  3715735     34607  Comp987487
# 1970-01-01 00:00:00.003715735  3715735     42813  Comp987487
#
#                                          DstDevice  Protocol    SrcPort  \
# Time_formatted
# ...

# %% [markdown]
# ## Timeseries plots

# %% [markdown]
# ### Anomlies over time

# %%
plt.hist(anomalies['Time'], bins=50, alpha=0.5, label='Anomalies')
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Histogram of Anomalies Over Time')
plt.legend()
plt.show()

# %% [markdown]
# ### Anomlies and normals logs over time

# %%
plt.hist(normal_logs['Time'], bins=50, alpha=0.5, label='Normal Logs')
plt.hist(anomalies['Time'], bins=50, alpha=0.5, label='Anomalies')
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Histogram of Normal Logs and Anomalies Over Time')
plt.legend()
plt.show()

# %% [markdown]
# ### Anomalies per column

# %%
def show_column_with_anomalies(column):
    plt.figure(figsize=(12, 6))
    plt.scatter(anomalies.index, anomalies[column], color='red', label='Outliers', s=50)
    plt.scatter(features.index, features[column], color='blue', label='Normal Data', marker='o', s=5)
    plt.title(f'Time Series of {column} with Outliers')
    plt.xlabel('Time')
    plt.ylabel(column)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
show_column_with_anomalies("Duration")

# %%
show_column_with_anomalies("SrcPackets")

# %%
show_column_with_anomalies("DstPackets")

# %%
show_column_with_anomalies("SrcBytes")

# %%
show_column_with_anomalies("DstBytes")

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Anomaly detection using `LocalOutlierFactor` model
#
# Local Outlier Factor (LOF) is an unsupervised anomaly detection algorithm used to identify outliers in datasets. It calculates the local density deviation of a data point with respect to its neighbors and identifies points with significantly lower density as outliers. LOF assigns an anomaly score to each data point, with higher scores indicating higher likelihood of being an outlier. It's particularly effective for detecting outliers in high-dimensional datasets and is relatively robust to varying densities in different regions of the dataset.

# %%
from sklearn.neighbors import LocalOutlierFactor

# Train Local Outlier Factor model
lof_model = LocalOutlierFactor(contamination=0.1)
lof_predictions = lof_model.fit_predict(features)
lof_anomalies = df[lof_predictions == -1]
lof_normal_logs = df[predictions != -1]


# Print number of anomalies
number_of_logs = df.size
number_of_lof_anomalies = lof_anomalies.size
print(f"Number of logs: {number_of_logs}") 
print(f"Number of anomalies: {number_of_lof_anomalies}")
print(f"Percent of anomalies: {100 * number_of_lof_anomalies / number_of_logs} %")

# Print the anomalies
print("Anomalies using Local Outlier Factor:")
print(lof_anomalies)
# Out:
# Number of logs: 11534336
# Number of anomalies: 1153427
# Percent of anomalies: 9.999942779541016 %
# Anomalies using Local Outlier Factor:
#                                   Time  Duration   SrcDevice        DstDevice  \
# Time_formatted
# 1970-01-01 00:00:00.003715200  3715200         0  Comp965724  ActiveDirectory
# 1970-01-01 00:00:00.003715200  3715200         0  Comp364445       Comp977866
# 1970-01-01 00:00:00.003715200  3715200         0  Comp097048  ActiveDirectory
# 1970-01-01 00:00:00.003715200  3715200         0  Comp073375       Comp186884
# 1970-01-01 00:00:00.003715200  3715200         0  Comp584379  ActiveDirectory
# ...                                ...       ...         ...              ...
# 1970-01-01 00:00:00.003715736  3715736         1  Comp867980       Comp200569
# 1970-01-01 00:00:00.003715736  3715736         1  Comp867980       Comp200569
# 1970-01-01 00:00:00.003715736  3715736         1  Comp867980  ActiveDirectory
# ...

# %% [markdown]
# ## Timeseries plots

# %% [markdown]
# ### Anomlies over time

# %%
plt.hist(lof_anomalies['Time'], bins=50, alpha=0.5, label='Anomalies')
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Histogram of Anomalies Over Time')
plt.legend()
plt.show()

# %% [markdown]
# ### Anomlies and normals logs over time

# %%
plt.hist(lof_normal_logs['Time'], bins=50, alpha=0.5, label='Normal Logs')
plt.hist(lof_anomalies['Time'], bins=50, alpha=0.5, label='Anomalies')
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Histogram of Normal Logs and Anomalies Over Time')
plt.legend()
plt.show()

# %% [markdown]
# ### Anomalies per column

# %%
def show_column_with_lof_anomalies(column):
    plt.figure(figsize=(12, 6))
    plt.scatter(lof_anomalies.index, lof_anomalies[column], color='red', label='Outliers', s=50)
    plt.scatter(features.index, features[column], color='blue', label='Normal Data', marker='o', s=5)
    plt.title(f'Time Series of {column} with Outliers')
    plt.xlabel('Time')
    plt.ylabel(column)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
show_column_with_lof_anomalies("Duration")

# %%
show_column_with_lof_anomalies("SrcPackets")

# %%
show_column_with_lof_anomalies("DstPackets")

# %%
show_column_with_lof_anomalies("SrcBytes")

# %%
show_column_with_lof_anomalies("DstBytes")
